# %% [markdown]
# ## Imports

# %%
import os
import json
import re

# from sklearn.model_selection import train_test_split

# %%
DATA_PATH = os.path.abspath("../data/datasets/ner-swiss-receipts-test.json")

# %%
with open(DATA_PATH, "r", encoding="utf-8") as file:
    dataset = json.load(file)

dataset
# Out:
# [{'image_name': 'swiss_receipt_121.jpeg',
#   'text': 'Bäckerei Konditorei\nCafe Moos Fabienne GmbH\nAmlehrıstrasse 48\n\n6005 sriens\n\nTelefon: 041 310 23 id\ninfeübeck-moos.ch\n\nWu, beck-mMOOoS.ch\n\nRechnung\n\njerumzett Beleg Nr.\nz5.,05,2022 OT: 27 S3097\nKu Fr, ’kg kg Fr,\nSuttergip feli\nStk, 1,40 7,60\nLausengipfeli\nStk, 1,40 170\nTotal CHF 1 4 „Ol\n€ 13,59\n\nDC ErT Ir er 2 Er PerFe re\n\n',
#   'entities': [[211, 240, 'RECEIPT_ITEM'],
#    [211, 225, 'RECEIPT_ITEM_NAME'],
#    [236, 240, 'RECEIPT_ITEM_PRICE'],
#    [241, 268, 'RECEIPT_ITEM'],
#    [241, 254, 'RECEIPT_ITEM_NAME'],
#    [265, 268, 'RECEIPT_ITEM_PRICE']]},
#  {'image_name': 'swiss_receipt_4.jpeg',
#   'text': 'BERSHKA\n\nCHE-100.6492.311 TVvA\nITX Retail Suisse SARL\n\nMall of Switzerland\nEbik-Square Strasse ]\n6030 Ebikon\nTel: 091 440 33 72\n\n14.12.2024 15:06 14408\n12275 063131 01 Trans: 272236\nTAP MwST MGE PREIS SUMME  T\n\nSHB 8.10 1 47.90 47.90 V\n10001827 0743453880504 PULLOVER\n\nNetto gesamt 44.31\nMUST 8.10\n\nGESAMT\n\n(1 : Fr.0.9385)\nb1.04EUR\n\nOnline EURDCARD Fr.47.90\n\n',
#   'entities': [[211, 267, 'RECEIPT_ITEM'],
#    [217, 218, 'RECEIPT_ITEM_QUANTITY'],
#    [259, 267, 'RECEIPT_ITEM_NAME'],
#    [228, 233, 'RECEIPT_ITEM_PRICE']]},
#  {'image_name': 'swiss_receipt_47.jpeg',
#   'text': 'Moosbacnstrasse I\n8910 Affoltern a.A.\nTel 044 585 91 22\n\nBELEG\n\n#CSO Rechnungsnummer : 65 POSEJ Order:\nKASSE 31- 1670472022 21:34:51\n\nANZ ARTIKEL TOTAL\n1 Big Mac 6.90\n1 Filet-0-Fish 5,90\n1 Medium Pommes Frites 4.50\n1 Keine Sauce\n1 Coca-Cola 0.4L 3,50\n\nINNEN TOTAL 20.80\nMastercard 20.80\n\nSst.Nr. CHE -449.055.085 MWST\nSAT, BRUTTO MWST\nsick, MwSt  1.70R 20.00 1.49\n KUNDENBELEG #\n\nBUCHUNG\n\nMC payPass\nktlos\n\nON\nKÄKKKKKKKXKRXIOT\n\n16.04.2022 21:34: 10\nIrm-Id; 101200994\n\n',
#   'entities': [[152, 166, 'RECEIPT_ITEM'],
#    [152, 153, 'RECEIPT_ITEM_QUANTITY'],
#    [154, 161, 'RECEIPT_ITEM_NAME'],
#    [162, 166, 'RECEIPT_ITEM_PRICE'],
#    [167, 186, 'RECEIPT_ITEM'],
#    [167, 168, 'RECEIPT_ITEM_QUANTITY'],
#    [169, 181, 'RECEIPT_ITEM_NAME'],
#    [182, 186, 'RECEIPT_ITEM_PRICE'],
#    [187, 214, 'RECEIPT_ITEM'],
#    [187, 188, 'RECEIPT_ITEM_QUANTITY'],
#    [189, 209, 'RECEIPT_ITEM_NAME'],
#    [210, 214, 'RECEIPT_ITEM_PRICE'],
#    [229, 250, 'RECEIPT_ITEM'],
#    [229, 230, 'RECEIPT_ITEM_QUANTITY'],
#    [231, 245, 'RECEIPT_ITEM_NAME'],
#    [246, 250, 'RECEIPT_ITEM_PRICE']]},
#  {'image_name': 'swiss_receipt_26.jpeg',
#   'text': 'RISTORANTE PIZZERIA\n\nHofmattweg 6 CH-6010 Kriens\nTelefon x41 (0)41 320 34 34\nWww.pizzeria-hofmatt.ch\nEL STITTENENEEETELETETTRTTETER TER T TE\n\n#0001 Kasse 1 08.12.2022\n\nRechnungNr.: 87387\nUrsprüngliche RechnungNr.: 87386\n\nT-Nr. 6\n2 75c1 Anselmi 49.00 98.00\n2 75 Terra de Alter Re 55.00 #110.00\n3 500] Cola 6.50 x19.50\n5 Fl Cola 4.90 x24.50\n\n3 5dl Henniez mit KS 6.50 x19.50\n2 It Henniez mit KS 9.80 x19.60\n1 3d] Henniez mit KS 4.90  x4.90\n1 7.5 dl Granderwasser\n\n2 Kaffee Cröme 4.90  x9.80\n7 Espresso 4.90 x34.30\n1 Kaffe Zwetschge 6.50  x8.50\n1 Menu 3 27.50 x27.50\n\nı Nüsslisalat Mimosa 14.50 x14.50\n2 Tagliatel ührısiina 293.50 x47.00\n1 Gnocchi della casa 26.50 x26.50\n1 Schweins-cordon-bleu 38.00 x38.00\n1 Chicken Nuggets 11.50 11.50\n2 Pizza Margherita 17.50 x35.00\n1 Pizza Prosciutto 21.50 21.50\n1 Pizza Pollino spec. 25.50 x25.50\n1 Pizza Pollino spec. 25.50 x25.50\n2 Pizza 506 25.50 x51.00\n1 Pizza Prosc e Funghi 21.50 21.50\n1 Pizza Fiorentina 23.50 x23.50\n\n1 Pizza Calzone 23.50 #23.50\n1 Pizza Mascarpone 27.50 x27.50\n1 Pizza Möcke 27.50 x27.50\n1 172 Pizza Fantasia 23.50 23.50\n1 Kugel Glace 3.80  #3.60\nZwischensumme 820.70\nTotal in Euro x863.09\n\niR 0;\n\nN\n\n',
#   'entities': [[229, 255, 'RECEIPT_ITEM'],
#    [229, 230, 'RECEIPT_ITEM_QUANTITY'],
#    [231, 243, 'RECEIPT_ITEM_NAME'],
#    [250, 255, 'RECEIPT_ITEM_PRICE'],
#    [256, 292, 'RECEIPT_ITEM'],
#    [256, 257, 'RECEIPT_ITEM_QUANTITY'],
#    [258, 278, 'RECEIPT_ITEM_NAME'],
#    [286, 292, 'RECEIPT_ITEM_PRICE'],
#    [293, 316, 'RECEIPT_ITEM'],
#    [293, 294, 'RECEIPT_ITEM_QUANTITY'],
#    [295, 304, 'RECEIPT_ITEM_NAME'],
#    [311, 316, 'RECEIPT_ITEM_PRICE'],
#    [317, 338, 'RECEIPT_ITEM'],
#    [317, 318, 'RECEIPT_ITEM_QUANTITY'],
#    [319, 326, 'RECEIPT_ITEM_NAME'],
#    [333, 338, 'RECEIPT_ITEM_PRICE'],
#    [340, 372, 'RECEIPT_ITEM'],
#    [340, 341, 'RECEIPT_ITEM_QUANTITY'],
#    [342, 360, 'RECEIPT_ITEM_NAME'],
#    [367, 372, 'RECEIPT_ITEM_PRICE'],
#    [373, 404, 'RECEIPT_ITEM'],
#    [373, 374, 'RECEIPT_ITEM_QUANTITY'],
#    [375, 392, 'RECEIPT_ITEM_NAME'],
#    [399, 404, 'RECEIPT_ITEM_PRICE'],
#    [405, 437, 'RECEIPT_ITEM'],
#    [405, 406, 'RECEIPT_ITEM_QUANTITY'],
#    [407, 425, 'RECEIPT_ITEM_NAME'],
#    [433, 437, 'RECEIPT_ITEM_PRICE'],
#    [462, 488, 'RECEIPT_ITEM'],
#    [462, 463, 'RECEIPT_ITEM_QUANTITY'],
#    [464, 476, 'RECEIPT_ITEM_NAME'],
#    [484, 488, 'RECEIPT_ITEM_PRICE'],
#    [489, 511, 'RECEIPT_ITEM'],
#    [489, 490, 'RECEIPT_ITEM_QUANTITY'],
#    [491, 499, 'RECEIPT_ITEM_NAME'],
#    [506, 511, 'RECEIPT_ITEM_PRICE'],
#    [512, 541, 'RECEIPT_ITEM'],
#    [512, 513, 'RECEIPT_ITEM_QUANTITY'],
#    [514, 529, 'RECEIPT_ITEM_NAME'],
#    [537, 541, 'RECEIPT_ITEM_PRICE'],
#    [542, 563, 'RECEIPT_ITEM'],
#    [542, 543, 'RECEIPT_ITEM_QUANTITY'],
#    [544, 550, 'RECEIPT_ITEM_NAME'],
#    [558, 563, 'RECEIPT_ITEM_PRICE'],
#    [565, 598, 'RECEIPT_ITEM'],
#    [565, 566, 'RECEIPT_ITEM_QUANTITY'],
#    [567, 585, 'RECEIPT_ITEM_NAME'],
#    [593, 598, 'RECEIPT_ITEM_PRICE'],
#    [599, 634, 'RECEIPT_ITEM'],
#    [599, 600, 'RECEIPT_ITEM_QUANTITY'],
#    [601, 620, 'RECEIPT_ITEM_NAME'],
#    [629, 634, 'RECEIPT_ITEM_PRICE'],
#    [635, 668, 'RECEIPT_ITEM'],
#    [635, 636, 'RECEIPT_ITEM_QUANTITY'],
#    [637, 655, 'RECEIPT_ITEM_NAME'],
#    [663, 668, 'RECEIPT_ITEM_PRICE'],
#    [669, 704, 'RECEIPT_ITEM'],
#    [669, 670, 'RECEIPT_ITEM_QUANTITY'],
#    [671, 691, 'RECEIPT_ITEM_NAME'],
#    [699, 704, 'RECEIPT_ITEM_PRICE'],
#    [705, 734, 'RECEIPT_ITEM'],
#    [705, 706, 'RECEIPT_ITEM_QUANTITY'],
#    [707, 722, 'RECEIPT_ITEM_NAME'],
#    [729, 734, 'RECEIPT_ITEM_PRICE'],
#    [735, 766, 'RECEIPT_ITEM'],
#    [735, 736, 'RECEIPT_ITEM_QUANTITY'],
#    [737, 753, 'RECEIPT_ITEM_NAME'],
#    [761, 766, 'RECEIPT_ITEM_PRICE'],
#    [767, 797, 'RECEIPT_ITEM'],
#    [767, 768, 'RECEIPT_ITEM_QUANTITY'],
#    [769, 785, 'RECEIPT_ITEM_NAME'],
#    [792, 797, 'RECEIPT_ITEM_PRICE'],
#    [928, 959, 'RECEIPT_ITEM'],
#    [928, 929, 'RECEIPT_ITEM_QUANTITY'],
#    [930, 946, 'RECEIPT_ITEM_NAME'],
#    [954, 959, 'RECEIPT_ITEM_PRICE'],
#    [961, 989, 'RECEIPT_ITEM'],
#    [961, 962, 'RECEIPT_ITEM_QUANTITY'],
#    [963, 976, 'RECEIPT_ITEM_NAME'],
#    [984, 989, 'RECEIPT_ITEM_PRICE'],
#    [990, 1021, 'RECEIPT_ITEM'],
#    [990, 991, 'RECEIPT_ITEM_QUANTITY'],
#    [992, 1008, 'RECEIPT_ITEM_NAME'],
#    [1016, 1021, 'RECEIPT_ITEM_PRICE'],
#    [1022, 1048, 'RECEIPT_ITEM'],
#    [1022, 1023, 'RECEIPT_ITEM_QUANTITY'],
#    [1024, 1035, 'RECEIPT_ITEM_NAME'],
#    [1043, 1048, 'RECEIPT_ITEM_PRICE'],
#    [1049, 1081, 'RECEIPT_ITEM'],
#    [1049, 1050, 'RECEIPT_ITEM_QUANTITY'],
#    [1051, 1069, 'RECEIPT_ITEM_NAME'],
#    [1076, 1081, 'RECEIPT_ITEM_PRICE'],
#    [1082, 1107, 'RECEIPT_ITEM'],
#    [1082, 1083, 'RECEIPT_ITEM_QUANTITY'],
#    [1084, 1095, 'RECEIPT_ITEM_NAME'],
#    [1103, 1107, 'RECEIPT_ITEM_PRICE']]},
#  {'image_name': 'swiss_receipt_81.jpeg',
#   'text': 'SHMANGHAI LUZERN "\'lß\n\nCHINA RENTAURZANT ä TAKE AWAY\n\nShanghai Nr. 3\nHaldenstrasse 23 , 6004 Luzerrı\nTelefon 041 470 55 11\n\nCHE-113.043.312 MWST\n\n. RECHNUNG\niﬂg Datum: 23.04.2022 6242 Zeit: 20:04\ni Tisch 5\n1 x 3321 Coca Cala 4,60\n1 x 3321 Coca Cala Zero 4,60\n1 x 3501 Arkina mit 4,50\n1 x 3021 Hopfenperle 5 .30\n2 x 5021 Hopfenperle 7.00 14,00\n1 x Wantan 13.50\n2 x ä la Singapur Huhn 24.50 493.00\n1 x Kunpo-Art Rind 33 .50\n1 x Szechuan-Art Huhn 27 .50\n1 x Szechuan-Art Rind 33 .50\n1 x Beilage Gebr. Nudaln B, 50\nTOTAL HE 9880\nEUR\n\n198 .50\n\nNett st Bruti\nB - Must 7.7 184.31 1ä“15 °.\n\n Zahlart: Bar\n\n',
#   'entities': [[206, 229, 'RECEIPT_ITEM'],
#    [206, 209, 'RECEIPT_ITEM_QUANTITY'],
#    [210, 224, 'RECEIPT_ITEM_NAME'],
#    [225, 229, 'RECEIPT_ITEM_PRICE'],
#    [230, 258, 'RECEIPT_ITEM'],
#    [230, 233, 'RECEIPT_ITEM_QUANTITY'],
#    [234, 253, 'RECEIPT_ITEM_NAME'],
#    [254, 258, 'RECEIPT_ITEM_PRICE'],
#    [259, 283, 'RECEIPT_ITEM'],
#    [259, 262, 'RECEIPT_ITEM_QUANTITY'],
#    [263, 278, 'RECEIPT_ITEM_NAME'],
#    [279, 283, 'RECEIPT_ITEM_PRICE'],
#    [284, 310, 'RECEIPT_ITEM'],
#    [284, 287, 'RECEIPT_ITEM_QUANTITY'],
#    [288, 304, 'RECEIPT_ITEM_NAME'],
#    [305, 310, 'RECEIPT_ITEM_PRICE'],
#    [311, 342, 'RECEIPT_ITEM'],
#    [311, 314, 'RECEIPT_ITEM_QUANTITY'],
#    [315, 331, 'RECEIPT_ITEM_NAME'],
#    [337, 342, 'RECEIPT_ITEM_PRICE'],
#    [343, 359, 'RECEIPT_ITEM'],
#    [343, 346, 'RECEIPT_ITEM_QUANTITY'],
#    [347, 353, 'RECEIPT_ITEM_NAME'],
#    [354, 359, 'RECEIPT_ITEM_PRICE'],
#    [360, 395, 'RECEIPT_ITEM'],
#    [360, 363, 'RECEIPT_ITEM_QUANTITY'],
#    [364, 382, 'RECEIPT_ITEM_NAME'],
#    [389, 395, 'RECEIPT_ITEM_PRICE'],
#    [396, 421, 'RECEIPT_ITEM'],
#    [396, 399, 'RECEIPT_ITEM_QUANTITY'],
#    [400, 414, 'RECEIPT_ITEM_NAME'],
#    [415, 421, 'RECEIPT_ITEM_PRICE'],
#    [422, 450, 'RECEIPT_ITEM'],
#    [422, 425, 'RECEIPT_ITEM_QUANTITY'],
#    [426, 443, 'RECEIPT_ITEM_NAME'],
#    [444, 450, 'RECEIPT_ITEM_PRICE'],
#    [451, 479, 'RECEIPT_ITEM'],
#    [451, 454, 'RECEIPT_ITEM_QUANTITY'],
#    [455, 472, 'RECEIPT_ITEM_NAME'],
#    [473, 479, 'RECEIPT_ITEM_PRICE'],
#    [480, 510, 'RECEIPT_ITEM'],
#    [480, 483, 'RECEIPT_ITEM_QUANTITY'],
#    [484, 504, 'RECEIPT_ITEM_NAME'],
#    [505, 510, 'RECEIPT_ITEM_PRICE']]},
#  {'image_name': 'swiss_receipt_69.jpeg',
#   'text': 'tt JE\nBachmann\n(U\n\nConfiserie Bachmann AG\nSurseepark\nBahnhofstrasse 28\n6210 Sursee\nTel. 41 41 227 70 70\nwww.confiserie.ch\nWLAN Passwort 2h: Schutzengeli\n\nRechnung\nBeleg Nr. 154198\nDatum’Zeit 24.01.2022 12:37:53\nCHF\nPaillasse dunkel 4.30\nSilser Zöpfli Thon 4.60\nTotal 8.90CHF\nEFT 8.90CHF\nZu verst. Netto 8.68\nUmsatz inkl. 2.5 8.90\nMWSt 2.5X 0.22\n\nBäckerei-Confiserie-Cafe\nBachmann\n6210 Sursee\n\n',
#   'entities': [[215, 236, 'RECEIPT_ITEM'],
#    [215, 231, 'RECEIPT_ITEM_NAME'],
#    [232, 236, 'RECEIPT_ITEM_PRICE'],
#    [237, 260, 'RECEIPT_ITEM'],
#    [237, 255, 'RECEIPT_ITEM_NAME'],
#    [256, 260, 'RECEIPT_ITEM_PRICE']]},
#  {'image_name': 'swiss_receipt_48.jpeg',
#   'text': 'Für mich und dich.\n\nWillisau\n\nArtikel Menge Preis Aktion Total\n\nQRP IPS Halbrahnpast 2 29 4.00\n\nIOTAL CHF\n\nNastercard\n\nBuchung Dehit Mastercard Gontactless\nKEKKRAKNKANNGION\n\n11.04.2022 17:49:00\n#31475588”00080018519396060000000024\n\nTotal-EFT CHF:\n\n600P GENOSSENSCHAFT, CHE-116.311.185 MUST\nRT TO MUST\n2.50 Im\n\n',
#   'entities': [[64, 94, 'RECEIPT_ITEM'],
#    [85, 86, 'RECEIPT_ITEM_QUANTITY'],
#    [64, 84, 'RECEIPT_ITEM_NAME'],
#    [90, 94, 'RECEIPT_ITEM_PRICE']]},
#  {'image_name': 'swiss_receipt_97.jpeg',
#   'text': 'kestaurant Lio\n\nPoststrasse 2 9494 Schaan\n\nRechnung Nr.11-3521 18:53:16 12.09,2021\n\nl n n a Al n n k k P 0n u E dr drn Mk n M M n 20 Wn Mal D, mnn ar an W\n\n2x Piz Sardona 0.75 Fr 7.50 Fr 15.00\n5x Coca Cola Fr 4.70 Fr 23.50\n7x Panach sauer 3d] Fr 4,70 Fr 9.40\n2x Pesca Galvanina Fr 5.50 Fr 11.00\n2x Beef Tatar Fr 27.00 Fr 54.00\n1x Tagessuppe Fr 10.00 Fr 10.00\n4x Pizza Parma Fr 26.00 Fr 104,00\n2x Pizza Prosciutto Fr 22.00 Fr 44,.00\n1x Ravioli di Manzo Fr 30.00 Fr 30,.00\n1x Pizza Margeritha Fr 16.00 Fr 18.00\n3x Lavakuchen Fr 15.00 Fr 45.00\n2x Kaffee Fr 4,50 Fr 9.00\n1x Doppelter Espres Fr 5.50 Fr 5.50\n1x Golden Toblerone Fr 17.00 Fr 17.00\n1x 1 Kugel Eis Fr 3.00\n Zitronen sorbet\n\nTotal Fr 398.40\n\n.. ‚Gegeben (Bar)\n\n',
#   'entities': [[156, 192, 'RECEIPT_ITEM'],
#    [156, 158, 'RECEIPT_ITEM_QUANTITY'],
#    [159, 175, 'RECEIPT_ITEM_NAME'],
#    [187, 192, 'RECEIPT_ITEM_PRICE'],
#    [193, 222, 'RECEIPT_ITEM'],
#    [193, 194, 'RECEIPT_ITEM_QUANTITY'],
#    [196, 205, 'RECEIPT_ITEM_NAME'],
#    [217, 222, 'RECEIPT_ITEM_PRICE'],
#    [223, 258, 'RECEIPT_ITEM'],
#    [223, 225, 'RECEIPT_ITEM_QUANTITY'],
#    [226, 242, 'RECEIPT_ITEM_NAME'],
#    [254, 258, 'RECEIPT_ITEM_PRICE'],
#    [259, 294, 'RECEIPT_ITEM'],
#    [259, 261, 'RECEIPT_ITEM_QUANTITY'],
#    [262, 277, 'RECEIPT_ITEM_NAME'],
#    [289, 294, 'RECEIPT_ITEM_PRICE'],
#    [295, 326, 'RECEIPT_ITEM'],
#    [295, 297, 'RECEIPT_ITEM_QUANTITY'],
#    [298, 308, 'RECEIPT_ITEM_NAME'],
#    [321, 326, 'RECEIPT_ITEM_PRICE'],
#    [327, 358, 'RECEIPT_ITEM'],
#    [327, 329, 'RECEIPT_ITEM_QUANTITY'],
#    [330, 340, 'RECEIPT_ITEM_NAME'],
#    [344, 349, 'RECEIPT_ITEM_PRICE'],
#    [353, 358, 'RECEIPT_ITEM_PRICE'],
#    [359, 392, 'RECEIPT_ITEM'],
#    [359, 361, 'RECEIPT_ITEM_QUANTITY'],
#    [362, 373, 'RECEIPT_ITEM_NAME'],
#    [386, 392, 'RECEIPT_ITEM_PRICE'],
#    [393, 431, 'RECEIPT_ITEM'],
#    [393, 395, 'RECEIPT_ITEM_QUANTITY'],
#    [396, 412, 'RECEIPT_ITEM_NAME'],
#    [425, 431, 'RECEIPT_ITEM_PRICE'],
#    [432, 470, 'RECEIPT_ITEM'],
#    [432, 434, 'RECEIPT_ITEM_QUANTITY'],
#    [435, 451, 'RECEIPT_ITEM_NAME'],
#    [464, 470, 'RECEIPT_ITEM_PRICE'],
#    [471, 508, 'RECEIPT_ITEM'],
#    [471, 473, 'RECEIPT_ITEM_QUANTITY'],
#    [474, 490, 'RECEIPT_ITEM_NAME'],
#    [503, 508, 'RECEIPT_ITEM_PRICE'],
#    [509, 540, 'RECEIPT_ITEM'],
#    [509, 511, 'RECEIPT_ITEM_QUANTITY'],
#    [512, 522, 'RECEIPT_ITEM_NAME'],
#    [535, 540, 'RECEIPT_ITEM_PRICE'],
#    [541, 566, 'RECEIPT_ITEM'],
#    [541, 543, 'RECEIPT_ITEM_QUANTITY'],
#    [544, 550, 'RECEIPT_ITEM_NAME'],
#    [562, 566, 'RECEIPT_ITEM_PRICE'],
#    [567, 602, 'RECEIPT_ITEM'],
#    [567, 569, 'RECEIPT_ITEM_QUANTITY'],
#    [570, 586, 'RECEIPT_ITEM_NAME'],
#    [590, 594, 'RECEIPT_ITEM_PRICE'],
#    [598, 602, 'RECEIPT_ITEM_PRICE'],
#    [603, 640, 'RECEIPT_ITEM'],
#    [603, 605, 'RECEIPT_ITEM_QUANTITY'],
#    [606, 622, 'RECEIPT_ITEM_NAME'],
#    [626, 631, 'RECEIPT_ITEM_PRICE'],
#    [635, 640, 'RECEIPT_ITEM_PRICE'],
#    [641, 663, 'RECEIPT_ITEM'],
#    [641, 643, 'RECEIPT_ITEM_QUANTITY'],
#    [644, 655, 'RECEIPT_ITEM_NAME'],
#    [659, 663, 'RECEIPT_ITEM_PRICE']]},
#  {'image_name': 'swiss_receipt_33.jpeg',
#   'text': '. u\n. Bückerci\nKonditorei\n\nSteiner\nBäckerei Konditorei Cafe\nWolhuserstrasse 4\n\n6122 Menznau\n\nTel. 041 493 11 26\n\nUID-Nr.: CHE-110.477.255 MWOT\n\nRECHNUNG 42384 14.12.2022 08:49\nCHFJEh CHF\n\nVe een ne ee ann re ie en et Annan 2 bee\n\ni Buttergipfeli [ 1.60\n1 Weggli C 1.30\n\n1 Lebensmittel [ 12.00\n\nu En je an einher 2 nn Arena\n\nEndbetrag: CHF 14.90\n\nEEE\nNetto Must Brutto\n14.54 0.35 1A,\n\nC- Hust 2.53\nZahlart:\n\nKreditkarten\n\nDe A\n\nselfservice, Bäckerei\n',
#   'entities': [[230, 252, 'RECEIPT_ITEM'],
#    [230, 231, 'RECEIPT_ITEM_QUANTITY'],
#    [232, 245, 'RECEIPT_ITEM_NAME'],
#    [248, 252, 'RECEIPT_ITEM_PRICE'],
#    [253, 268, 'RECEIPT_ITEM'],
#    [253, 254, 'RECEIPT_ITEM_QUANTITY'],
#    [255, 261, 'RECEIPT_ITEM_NAME'],
#    [264, 268, 'RECEIPT_ITEM_PRICE'],
#    [270, 292, 'RECEIPT_ITEM'],
#    [270, 271, 'RECEIPT_ITEM_QUANTITY'],
#    [272, 284, 'RECEIPT_ITEM_NAME'],
#    [287, 292, 'RECEIPT_ITEM_PRICE']]}]

# %%
data = []
for entry in dataset:
    text = entry["text"]
    entities = [entity for entity in entry["entities"] if entity[2] != 'RECEIPT_ITEM']
    data.append((text, {"entities": entities}))

data
# Out:
# [('Bäckerei Konditorei\nCafe Moos Fabienne GmbH\nAmlehrıstrasse 48\n\n6005 sriens\n\nTelefon: 041 310 23 id\ninfeübeck-moos.ch\n\nWu, beck-mMOOoS.ch\n\nRechnung\n\njerumzett Beleg Nr.\nz5.,05,2022 OT: 27 S3097\nKu Fr, ’kg kg Fr,\nSuttergip feli\nStk, 1,40 7,60\nLausengipfeli\nStk, 1,40 170\nTotal CHF 1 4 „Ol\n€ 13,59\n\nDC ErT Ir er 2 Er PerFe re\n\n',
#   {'entities': [[211, 225, 'RECEIPT_ITEM_NAME'],
#     [236, 240, 'RECEIPT_ITEM_PRICE'],
#     [241, 254, 'RECEIPT_ITEM_NAME'],
#     [265, 268, 'RECEIPT_ITEM_PRICE']]}),
#  ('BERSHKA\n\nCHE-100.6492.311 TVvA\nITX Retail Suisse SARL\n\nMall of Switzerland\nEbik-Square Strasse ]\n6030 Ebikon\nTel: 091 440 33 72\n\n14.12.2024 15:06 14408\n12275 063131 01 Trans: 272236\nTAP MwST MGE PREIS SUMME  T\n\nSHB 8.10 1 47.90 47.90 V\n10001827 0743453880504 PULLOVER\n\nNetto gesamt 44.31\nMUST 8.10\n\nGESAMT\n\n(1 : Fr.0.9385)\nb1.04EUR\n\nOnline EURDCARD Fr.47.90\n\n',
#   {'entities': [[217, 218, 'RECEIPT_ITEM_QUANTITY'],
#     [259, 267, 'RECEIPT_ITEM_NAME'],
#     [228, 233, 'RECEIPT_ITEM_PRICE']]}),
#  ('Moosbacnstrasse I\n8910 Affoltern a.A.\nTel 044 585 91 22\n\nBELEG\n\n#CSO Rechnungsnummer : 65 POSEJ Order:\nKASSE 31- 1670472022 21:34:51\n\nANZ ARTIKEL TOTAL\n1 Big Mac 6.90\n1 Filet-0-Fish 5,90\n1 Medium Pommes Frites 4.50\n1 Keine Sauce\n1 Coca-Cola 0.4L 3,50\n\nINNEN TOTAL 20.80\nMastercard 20.80\n\nSst.Nr. CHE -449.055.085 MWST\nSAT, BRUTTO MWST\nsick, MwSt  1.70R 20.00 1.49\n KUNDENBELEG #\n\nBUCHUNG\n\nMC payPass\nktlos\n\nON\nKÄKKKKKKKXKRXIOT\n\n16.04.2022 21:34: 10\nIrm-Id; 101200994\n\n',
#   {'entities': [[152, 153, 'RECEIPT_ITEM_QUANTITY'],
#     [154, 161, 'RECEIPT_ITEM_NAME'],
#     [162, 166, 'RECEIPT_ITEM_PRICE'],
#     [167, 168, 'RECEIPT_ITEM_QUANTITY'],
#     [169, 181, 'RECEIPT_ITEM_NAME'],
#     [182, 186, 'RECEIPT_ITEM_PRICE'],
#     [187, 188, 'RECEIPT_ITEM_QUANTITY'],
#     [189, 209, 'RECEIPT_ITEM_NAME'],
#     [210, 214, 'RECEIPT_ITEM_PRICE'],
#     [229, 230, 'RECEIPT_ITEM_QUANTITY'],
#     [231, 245, 'RECEIPT_ITEM_NAME'],
#     [246, 250, 'RECEIPT_ITEM_PRICE']]}),
#  ('RISTORANTE PIZZERIA\n\nHofmattweg 6 CH-6010 Kriens\nTelefon x41 (0)41 320 34 34\nWww.pizzeria-hofmatt.ch\nEL STITTENENEEETELETETTRTTETER TER T TE\n\n#0001 Kasse 1 08.12.2022\n\nRechnungNr.: 87387\nUrsprüngliche RechnungNr.: 87386\n\nT-Nr. 6\n2 75c1 Anselmi 49.00 98.00\n2 75 Terra de Alter Re 55.00 #110.00\n3 500] Cola 6.50 x19.50\n5 Fl Cola 4.90 x24.50\n\n3 5dl Henniez mit KS 6.50 x19.50\n2 It Henniez mit KS 9.80 x19.60\n1 3d] Henniez mit KS 4.90  x4.90\n1 7.5 dl Granderwasser\n\n2 Kaffee Cröme 4.90  x9.80\n7 Espresso 4.90 x34.30\n1 Kaffe Zwetschge 6.50  x8.50\n1 Menu 3 27.50 x27.50\n\nı Nüsslisalat Mimosa 14.50 x14.50\n2 Tagliatel ührısiina 293.50 x47.00\n1 Gnocchi della casa 26.50 x26.50\n1 Schweins-cordon-bleu 38.00 x38.00\n1 Chicken Nuggets 11.50 11.50\n2 Pizza Margherita 17.50 x35.00\n1 Pizza Prosciutto 21.50 21.50\n1 Pizza Pollino spec. 25.50 x25.50\n1 Pizza Pollino spec. 25.50 x25.50\n2 Pizza 506 25.50 x51.00\n1 Pizza Prosc e Funghi 21.50 21.50\n1 Pizza Fiorentina 23.50 x23.50\n\n1 Pizza Calzone 23.50 #23.50\n1 Pizza Mascarpone 27.50 x27.50\n1 Pizza Möcke 27.50 x27.50\n1 172 Pizza Fantasia 23.50 23.50\n1 Kugel Glace 3.80  #3.60\nZwischensumme 820.70\nTotal in Euro x863.09\n\niR 0;\n\nN\n\n',
#   {'entities': [[229, 230, 'RECEIPT_ITEM_QUANTITY'],
#     [231, 243, 'RECEIPT_ITEM_NAME'],
#     [250, 255, 'RECEIPT_ITEM_PRICE'],
#     [256, 257, 'RECEIPT_ITEM_QUANTITY'],
#     [258, 278, 'RECEIPT_ITEM_NAME'],
#     [286, 292, 'RECEIPT_ITEM_PRICE'],
#     [293, 294, 'RECEIPT_ITEM_QUANTITY'],
#     [295, 304, 'RECEIPT_ITEM_NAME'],
#     [311, 316, 'RECEIPT_ITEM_PRICE'],
#     [317, 318, 'RECEIPT_ITEM_QUANTITY'],
#     [319, 326, 'RECEIPT_ITEM_NAME'],
#     [333, 338, 'RECEIPT_ITEM_PRICE'],
#     [340, 341, 'RECEIPT_ITEM_QUANTITY'],
#     [342, 360, 'RECEIPT_ITEM_NAME'],
#     [367, 372, 'RECEIPT_ITEM_PRICE'],
#     [373, 374, 'RECEIPT_ITEM_QUANTITY'],
#     [375, 392, 'RECEIPT_ITEM_NAME'],
#     [399, 404, 'RECEIPT_ITEM_PRICE'],
#     [405, 406, 'RECEIPT_ITEM_QUANTITY'],
#     [407, 425, 'RECEIPT_ITEM_NAME'],
#     [433, 437, 'RECEIPT_ITEM_PRICE'],
#     [462, 463, 'RECEIPT_ITEM_QUANTITY'],
#     [464, 476, 'RECEIPT_ITEM_NAME'],
#     [484, 488, 'RECEIPT_ITEM_PRICE'],
#     [489, 490, 'RECEIPT_ITEM_QUANTITY'],
#     [491, 499, 'RECEIPT_ITEM_NAME'],
#     [506, 511, 'RECEIPT_ITEM_PRICE'],
#     [512, 513, 'RECEIPT_ITEM_QUANTITY'],
#     [514, 529, 'RECEIPT_ITEM_NAME'],
#     [537, 541, 'RECEIPT_ITEM_PRICE'],
#     [542, 543, 'RECEIPT_ITEM_QUANTITY'],
#     [544, 550, 'RECEIPT_ITEM_NAME'],
#     [558, 563, 'RECEIPT_ITEM_PRICE'],
#     [565, 566, 'RECEIPT_ITEM_QUANTITY'],
#     [567, 585, 'RECEIPT_ITEM_NAME'],
#     [593, 598, 'RECEIPT_ITEM_PRICE'],
#     [599, 600, 'RECEIPT_ITEM_QUANTITY'],
#     [601, 620, 'RECEIPT_ITEM_NAME'],
#     [629, 634, 'RECEIPT_ITEM_PRICE'],
#     [635, 636, 'RECEIPT_ITEM_QUANTITY'],
#     [637, 655, 'RECEIPT_ITEM_NAME'],
#     [663, 668, 'RECEIPT_ITEM_PRICE'],
#     [669, 670, 'RECEIPT_ITEM_QUANTITY'],
#     [671, 691, 'RECEIPT_ITEM_NAME'],
#     [699, 704, 'RECEIPT_ITEM_PRICE'],
#     [705, 706, 'RECEIPT_ITEM_QUANTITY'],
#     [707, 722, 'RECEIPT_ITEM_NAME'],
#     [729, 734, 'RECEIPT_ITEM_PRICE'],
#     [735, 736, 'RECEIPT_ITEM_QUANTITY'],
#     [737, 753, 'RECEIPT_ITEM_NAME'],
#     [761, 766, 'RECEIPT_ITEM_PRICE'],
#     [767, 768, 'RECEIPT_ITEM_QUANTITY'],
#     [769, 785, 'RECEIPT_ITEM_NAME'],
#     [792, 797, 'RECEIPT_ITEM_PRICE'],
#     [928, 929, 'RECEIPT_ITEM_QUANTITY'],
#     [930, 946, 'RECEIPT_ITEM_NAME'],
#     [954, 959, 'RECEIPT_ITEM_PRICE'],
#     [961, 962, 'RECEIPT_ITEM_QUANTITY'],
#     [963, 976, 'RECEIPT_ITEM_NAME'],
#     [984, 989, 'RECEIPT_ITEM_PRICE'],
#     [990, 991, 'RECEIPT_ITEM_QUANTITY'],
#     [992, 1008, 'RECEIPT_ITEM_NAME'],
#     [1016, 1021, 'RECEIPT_ITEM_PRICE'],
#     [1022, 1023, 'RECEIPT_ITEM_QUANTITY'],
#     [1024, 1035, 'RECEIPT_ITEM_NAME'],
#     [1043, 1048, 'RECEIPT_ITEM_PRICE'],
#     [1049, 1050, 'RECEIPT_ITEM_QUANTITY'],
#     [1051, 1069, 'RECEIPT_ITEM_NAME'],
#     [1076, 1081, 'RECEIPT_ITEM_PRICE'],
#     [1082, 1083, 'RECEIPT_ITEM_QUANTITY'],
#     [1084, 1095, 'RECEIPT_ITEM_NAME'],
#     [1103, 1107, 'RECEIPT_ITEM_PRICE']]}),
#  ('SHMANGHAI LUZERN "\'lß\n\nCHINA RENTAURZANT ä TAKE AWAY\n\nShanghai Nr. 3\nHaldenstrasse 23 , 6004 Luzerrı\nTelefon 041 470 55 11\n\nCHE-113.043.312 MWST\n\n. RECHNUNG\niﬂg Datum: 23.04.2022 6242 Zeit: 20:04\ni Tisch 5\n1 x 3321 Coca Cala 4,60\n1 x 3321 Coca Cala Zero 4,60\n1 x 3501 Arkina mit 4,50\n1 x 3021 Hopfenperle 5 .30\n2 x 5021 Hopfenperle 7.00 14,00\n1 x Wantan 13.50\n2 x ä la Singapur Huhn 24.50 493.00\n1 x Kunpo-Art Rind 33 .50\n1 x Szechuan-Art Huhn 27 .50\n1 x Szechuan-Art Rind 33 .50\n1 x Beilage Gebr. Nudaln B, 50\nTOTAL HE 9880\nEUR\n\n198 .50\n\nNett st Bruti\nB - Must 7.7 184.31 1ä“15 °.\n\n Zahlart: Bar\n\n',
#   {'entities': [[206, 209, 'RECEIPT_ITEM_QUANTITY'],
#     [210, 224, 'RECEIPT_ITEM_NAME'],
#     [225, 229, 'RECEIPT_ITEM_PRICE'],
#     [230, 233, 'RECEIPT_ITEM_QUANTITY'],
#     [234, 253, 'RECEIPT_ITEM_NAME'],
#     [254, 258, 'RECEIPT_ITEM_PRICE'],
#     [259, 262, 'RECEIPT_ITEM_QUANTITY'],
#     [263, 278, 'RECEIPT_ITEM_NAME'],
#     [279, 283, 'RECEIPT_ITEM_PRICE'],
#     [284, 287, 'RECEIPT_ITEM_QUANTITY'],
#     [288, 304, 'RECEIPT_ITEM_NAME'],
#     [305, 310, 'RECEIPT_ITEM_PRICE'],
#     [311, 314, 'RECEIPT_ITEM_QUANTITY'],
#     [315, 331, 'RECEIPT_ITEM_NAME'],
#     [337, 342, 'RECEIPT_ITEM_PRICE'],
#     [343, 346, 'RECEIPT_ITEM_QUANTITY'],
#     [347, 353, 'RECEIPT_ITEM_NAME'],
#     [354, 359, 'RECEIPT_ITEM_PRICE'],
#     [360, 363, 'RECEIPT_ITEM_QUANTITY'],
#     [364, 382, 'RECEIPT_ITEM_NAME'],
#     [389, 395, 'RECEIPT_ITEM_PRICE'],
#     [396, 399, 'RECEIPT_ITEM_QUANTITY'],
#     [400, 414, 'RECEIPT_ITEM_NAME'],
#     [415, 421, 'RECEIPT_ITEM_PRICE'],
#     [422, 425, 'RECEIPT_ITEM_QUANTITY'],
#     [426, 443, 'RECEIPT_ITEM_NAME'],
#     [444, 450, 'RECEIPT_ITEM_PRICE'],
#     [451, 454, 'RECEIPT_ITEM_QUANTITY'],
#     [455, 472, 'RECEIPT_ITEM_NAME'],
#     [473, 479, 'RECEIPT_ITEM_PRICE'],
#     [480, 483, 'RECEIPT_ITEM_QUANTITY'],
#     [484, 504, 'RECEIPT_ITEM_NAME'],
#     [505, 510, 'RECEIPT_ITEM_PRICE']]}),
#  ('tt JE\nBachmann\n(U\n\nConfiserie Bachmann AG\nSurseepark\nBahnhofstrasse 28\n6210 Sursee\nTel. 41 41 227 70 70\nwww.confiserie.ch\nWLAN Passwort 2h: Schutzengeli\n\nRechnung\nBeleg Nr. 154198\nDatum’Zeit 24.01.2022 12:37:53\nCHF\nPaillasse dunkel 4.30\nSilser Zöpfli Thon 4.60\nTotal 8.90CHF\nEFT 8.90CHF\nZu verst. Netto 8.68\nUmsatz inkl. 2.5 8.90\nMWSt 2.5X 0.22\n\nBäckerei-Confiserie-Cafe\nBachmann\n6210 Sursee\n\n',
#   {'entities': [[215, 231, 'RECEIPT_ITEM_NAME'],
#     [232, 236, 'RECEIPT_ITEM_PRICE'],
#     [237, 255, 'RECEIPT_ITEM_NAME'],
#     [256, 260, 'RECEIPT_ITEM_PRICE']]}),
#  ('Für mich und dich.\n\nWillisau\n\nArtikel Menge Preis Aktion Total\n\nQRP IPS Halbrahnpast 2 29 4.00\n\nIOTAL CHF\n\nNastercard\n\nBuchung Dehit Mastercard Gontactless\nKEKKRAKNKANNGION\n\n11.04.2022 17:49:00\n#31475588”00080018519396060000000024\n\nTotal-EFT CHF:\n\n600P GENOSSENSCHAFT, CHE-116.311.185 MUST\nRT TO MUST\n2.50 Im\n\n',
#   {'entities': [[85, 86, 'RECEIPT_ITEM_QUANTITY'],
#     [64, 84, 'RECEIPT_ITEM_NAME'],
#     [90, 94, 'RECEIPT_ITEM_PRICE']]}),
#  ('kestaurant Lio\n\nPoststrasse 2 9494 Schaan\n\nRechnung Nr.11-3521 18:53:16 12.09,2021\n\nl n n a Al n n k k P 0n u E dr drn Mk n M M n 20 Wn Mal D, mnn ar an W\n\n2x Piz Sardona 0.75 Fr 7.50 Fr 15.00\n5x Coca Cola Fr 4.70 Fr 23.50\n7x Panach sauer 3d] Fr 4,70 Fr 9.40\n2x Pesca Galvanina Fr 5.50 Fr 11.00\n2x Beef Tatar Fr 27.00 Fr 54.00\n1x Tagessuppe Fr 10.00 Fr 10.00\n4x Pizza Parma Fr 26.00 Fr 104,00\n2x Pizza Prosciutto Fr 22.00 Fr 44,.00\n1x Ravioli di Manzo Fr 30.00 Fr 30,.00\n1x Pizza Margeritha Fr 16.00 Fr 18.00\n3x Lavakuchen Fr 15.00 Fr 45.00\n2x Kaffee Fr 4,50 Fr 9.00\n1x Doppelter Espres Fr 5.50 Fr 5.50\n1x Golden Toblerone Fr 17.00 Fr 17.00\n1x 1 Kugel Eis Fr 3.00\n Zitronen sorbet\n\nTotal Fr 398.40\n\n.. ‚Gegeben (Bar)\n\n',
#   {'entities': [[156, 158, 'RECEIPT_ITEM_QUANTITY'],
#     [159, 175, 'RECEIPT_ITEM_NAME'],
#     [187, 192, 'RECEIPT_ITEM_PRICE'],
#     [193, 194, 'RECEIPT_ITEM_QUANTITY'],
#     [196, 205, 'RECEIPT_ITEM_NAME'],
#     [217, 222, 'RECEIPT_ITEM_PRICE'],
#     [223, 225, 'RECEIPT_ITEM_QUANTITY'],
#     [226, 242, 'RECEIPT_ITEM_NAME'],
#     [254, 258, 'RECEIPT_ITEM_PRICE'],
#     [259, 261, 'RECEIPT_ITEM_QUANTITY'],
#     [262, 277, 'RECEIPT_ITEM_NAME'],
#     [289, 294, 'RECEIPT_ITEM_PRICE'],
#     [295, 297, 'RECEIPT_ITEM_QUANTITY'],
#     [298, 308, 'RECEIPT_ITEM_NAME'],
#     [321, 326, 'RECEIPT_ITEM_PRICE'],
#     [327, 329, 'RECEIPT_ITEM_QUANTITY'],
#     [330, 340, 'RECEIPT_ITEM_NAME'],
#     [344, 349, 'RECEIPT_ITEM_PRICE'],
#     [353, 358, 'RECEIPT_ITEM_PRICE'],
#     [359, 361, 'RECEIPT_ITEM_QUANTITY'],
#     [362, 373, 'RECEIPT_ITEM_NAME'],
#     [386, 392, 'RECEIPT_ITEM_PRICE'],
#     [393, 395, 'RECEIPT_ITEM_QUANTITY'],
#     [396, 412, 'RECEIPT_ITEM_NAME'],
#     [425, 431, 'RECEIPT_ITEM_PRICE'],
#     [432, 434, 'RECEIPT_ITEM_QUANTITY'],
#     [435, 451, 'RECEIPT_ITEM_NAME'],
#     [464, 470, 'RECEIPT_ITEM_PRICE'],
#     [471, 473, 'RECEIPT_ITEM_QUANTITY'],
#     [474, 490, 'RECEIPT_ITEM_NAME'],
#     [503, 508, 'RECEIPT_ITEM_PRICE'],
#     [509, 511, 'RECEIPT_ITEM_QUANTITY'],
#     [512, 522, 'RECEIPT_ITEM_NAME'],
#     [535, 540, 'RECEIPT_ITEM_PRICE'],
#     [541, 543, 'RECEIPT_ITEM_QUANTITY'],
#     [544, 550, 'RECEIPT_ITEM_NAME'],
#     [562, 566, 'RECEIPT_ITEM_PRICE'],
#     [567, 569, 'RECEIPT_ITEM_QUANTITY'],
#     [570, 586, 'RECEIPT_ITEM_NAME'],
#     [590, 594, 'RECEIPT_ITEM_PRICE'],
#     [598, 602, 'RECEIPT_ITEM_PRICE'],
#     [603, 605, 'RECEIPT_ITEM_QUANTITY'],
#     [606, 622, 'RECEIPT_ITEM_NAME'],
#     [626, 631, 'RECEIPT_ITEM_PRICE'],
#     [635, 640, 'RECEIPT_ITEM_PRICE'],
#     [641, 643, 'RECEIPT_ITEM_QUANTITY'],
#     [644, 655, 'RECEIPT_ITEM_NAME'],
#     [659, 663, 'RECEIPT_ITEM_PRICE']]}),
#  ('. u\n. Bückerci\nKonditorei\n\nSteiner\nBäckerei Konditorei Cafe\nWolhuserstrasse 4\n\n6122 Menznau\n\nTel. 041 493 11 26\n\nUID-Nr.: CHE-110.477.255 MWOT\n\nRECHNUNG 42384 14.12.2022 08:49\nCHFJEh CHF\n\nVe een ne ee ann re ie en et Annan 2 bee\n\ni Buttergipfeli [ 1.60\n1 Weggli C 1.30\n\n1 Lebensmittel [ 12.00\n\nu En je an einher 2 nn Arena\n\nEndbetrag: CHF 14.90\n\nEEE\nNetto Must Brutto\n14.54 0.35 1A,\n\nC- Hust 2.53\nZahlart:\n\nKreditkarten\n\nDe A\n\nselfservice, Bäckerei\n',
#   {'entities': [[230, 231, 'RECEIPT_ITEM_QUANTITY'],
#     [232, 245, 'RECEIPT_ITEM_NAME'],
#     [248, 252, 'RECEIPT_ITEM_PRICE'],
#     [253, 254, 'RECEIPT_ITEM_QUANTITY'],
#     [255, 261, 'RECEIPT_ITEM_NAME'],
#     [264, 268, 'RECEIPT_ITEM_PRICE'],
#     [270, 271, 'RECEIPT_ITEM_QUANTITY'],
#     [272, 284, 'RECEIPT_ITEM_NAME'],
#     [287, 292, 'RECEIPT_ITEM_PRICE']]})]

# %%
# train, test = train_test_split(data, test_size=0.1)

# %% [markdown]
# ### Regex Baseline Model

# %%
quantity_pattern = r'(\d+\s*[xX]?)\s+'
item_name_pattern = r'([\w\s\-]+)\s+'
price_pattern = r'([\d]+[\.\,]\d{2})'

item_pattern = quantity_pattern + item_name_pattern + price_pattern

# %%
def extract_item_data(text):
    lines = text.split("\n")
    items = []
    for line in lines:
        found_items = re.findall(item_pattern, line)
        if found_items:
            items.append(found_items)
    flattened_items = [item for sublist in items for tuple in sublist for item in tuple]
    return flattened_items

# %% [markdown]
# ## Evaluation

# %%
def print_confusion_matrix(matrix, labels):
    """
    Prints a confusion matrix as a formatted string.

    Args:
        matrix (list of list of int): Confusion matrix as a 2D list.
        labels (list of str): Labels for the matrix.
    """
    max_label_length = max(len(label) for label in labels)
    padding = max_label_length + 2

    # Print header
    header = " " * padding + " ".join(f"{label:>{padding}}" for label in labels)
    print(f'{"":<15} Predicted Values')
    print(header)

    # Print each row
    for label, row in zip(labels, matrix):
        row_str = " ".join(f"{cell:>{padding}}" for cell in row)
        print(f"{label:>{padding}} {row_str}")

# %%
true_positive = []
false_positive = []
false_negative = []

for text, annotations in data:
    # Process the text
    ents = extract_item_data(text)

    # Prepare expected values (y)
    expected_entities = []
    for ent in annotations.get("entities"):
        if ent[2] != 'RECEIPT_ITEM':
            expected_entities.append(text[ent[0]:ent[1]])
    print(expected_entities)

    # Print recognized entities
    for text in ents:
        if text in expected_entities:
            true_positive.append(text)
            expected_entities.remove(text)
        else:
            false_positive.append(text)

    false_negative.extend(expected_entities)

# Example usage
labels = ["Entity", "No Entity"]
confusion_matrix = [
    [len(true_positive), len(false_negative)],
    [len(false_positive), '0'],
]

print('Confusion Matrix:')
print_confusion_matrix(confusion_matrix, labels)

print('\nPerformance Measures:')
precision = len(true_positive) / (len(true_positive) + len(false_positive))
recall = len(true_positive) / (len(true_positive) + len(false_negative))
f1_score = 2 * precision * recall / (precision + recall)
print('Precision: ' + str(precision))
print('Recall: ' + str(recall))
print('F1 Score: ' + str(f1_score))

# True-Positive = correct idetified entities
# false_positive = actual entity that was not identified
# False-negative = identified entity that is actually not a entity
# Out:
# ['Suttergip feli', '7,60', 'Lausengipfeli', '170']
# ['1', 'PULLOVER', '47.90']
# ['1', 'Big Mac', '6.90', '1', 'Filet-0-Fish', '5,90', '1', 'Medium Pommes Frites', '4.50', '1', 'Coca-Cola 0.4L', '3,50']
# ['2', '75c1 Anselmi', '98.00', '2', '75 Terra de Alter Re', '110.00', '3', '500] Cola', '19.50', '5', 'Fl Cola', '24.50', '3', '5dl Henniez mit KS', '19.50', '2', 'It Henniez mit KS', '19.60', '1', '3d] Henniez mit KS', '4.90', '2', 'Kaffee Cröme', '9.80', '7', 'Espresso', '34.30', '1', 'Kaffe Zwetschge', '8.50', '1', 'Menu 3', '27.50', 'ı', 'Nüsslisalat Mimosa', '14.50', '2', 'Tagliatel ührısiina', '47.00', '1', 'Gnocchi della casa', '26.50', '1', 'Schweins-cordon-bleu', '38.00', '1', 'Chicken Nuggets', '11.50', '2', 'Pizza Margherita', '35.00', '1', 'Pizza Prosciutto', '21.50', '1', 'Pizza Fiorentina', '23.50', '1', 'Pizza Calzone', '23.50', '1', 'Pizza Mascarpone', '27.50', '1', 'Pizza Möcke', '27.50', '1', '172 Pizza Fantasia', '23.50', '1', 'Kugel Glace', '3.60']
# ['1 x', '3321 Coca Cala', '4,60', '1 x', '3321 Coca Cala Zero', '4,60', '1 x', '3501 Arkina mit', '4,50', '1 x', '3021 Hopfenperle', '5 .30', '2 x', '5021 Hopfenperle', '14,00', '1 x', 'Wantan', '13.50', '2 x', 'ä la Singapur Huhn', '493.00', '1 x', 'Kunpo-Art Rind', '33 .50', '1 x', 'Szechuan-Art Huhn', '27 .50', '1 x', 'Szechuan-Art Rind', '33 .50', '1 x', 'Beilage Gebr. Nudaln', 'B, 50']
# ['Paillasse dunkel', '4.30', 'Silser Zöpfli Thon', '4.60']
# ['2', 'QRP IPS Halbrahnpast', '4.00']
# ['2x', 'Piz Sardona 0.75', '15.00', '5', 'Coca Cola', '23.50', '7x', 'Panach sauer 3d]', '9.40', '2x', 'Pesca Galvanina', '11.00', '2x', 'Beef Tatar', '54.00', '1x', 'Tagessuppe', '10.00', '10.00', '4x', 'Pizza Parma', '104,00', '2x', 'Pizza Prosciutto', '44,.00', '1x', 'Ravioli di Manzo', '30,.00', '1x', 'Pizza Margeritha', '18.00', '3x', 'Lavakuchen', '45.00', '2x', 'Kaffee', '9.00', '1x', 'Doppelter Espres', '5.50', '5.50', '1x', 'Golden Toblerone', '17.00', '17.00', '1x', '1 Kugel Eis', '3.00']
# ['i', 'Buttergipfeli', '1.60', '1', 'Weggli', '1.30', '1', 'Lebensmittel', '12.00']
# Confusion Matrix:
#                 Predicted Values
#                 Entity   No Entity
#      Entity         106          82
#   No Entity          50           0
#
# Performance Measures:
# Precision: 0.6794871794871795
# Recall: 0.5638297872340425
# F1 Score: 0.6162790697674418
